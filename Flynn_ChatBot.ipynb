# %% [markdown]
# # Making a Chatbot

# %% [markdown]
# ## Intro

# %% [markdown]
# So, I have always been interested in AI, NLP, and Chatbots, so I tried to make a basic chatbot using the an available intents file from <a href = "https://www.kaggle.com/datasets/elvinagammed/chatbots-intent-recognition-dataset?select=Intent.json"> kaggle. </a>
# <p> For this project I used a lot of online tutorials so some code might seem familiar </p>

# %% [markdown]
# ### Importing Libraries

# %% [markdown]
# The libraries we need for this are random to generate random responses; json, to read the intents.json file; pickle to store the model and later call it; nltk, or the natural language toolkit; and tensor flow's Keras to add neural network layers to the model.

# %%
import random
import json
import pickle
import numpy as np
import nltk
#!pip install tensorflow
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dushy\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\dushy\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\dushy\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# From NLTK we importer the WordNetLemmatizer. IN NLP we often hear stemmer and lemmatizer a lot which basically are used to reduce the length of the word. However, they both achieve it in different ways.
# <p> While stemmer usually removes the suffixes of a word to relate them, lemmatizer actually goes to the core word, or so I have read </p>
# <p> For example, [study, studies, studying] under a stemmer would become [study, stud, study] as it removes the suffixer. A lemmatizer will extract the core word/the lemma from these and therefore what we see would be [study, study, study.]
#     <p>In theory, lemmatizers are usually better for bigger applications of NLP as they can understand the context of the word...in theory. They can tell the difference between care and caring while a stemmer may store the latter as only "car" and not "the gerund of care"/"the act of taking care of someone."</p> </p>

# %% [markdown]
# ### Loading the json file and creating empty lists to store words, tags, documents

# %%
lemmatizer = WordNetLemmatizer()
#with open ("./intents.json") as d:
#    intents = json.loads(d).read()
intents = json.loads(open('./intents.json').read())

# %%
words = []
classes = []
documents = []
ignore_letters = ['?','!','.',',',':']

# %% [markdown]
# ### Reading the intents file and storing the conversation tags and texts

# %%
for intent in intents['intents']:
    for pattern in intent['texts']:
        word_list = nltk.word_tokenize(pattern)
        words.extend(word_list)
        documents.append((word_list, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

words = [lemmatizer.lemmatize(word) for word in words if word not in ignore_letters]
words = sorted(set(words))

classes = sorted(set(classes))

pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

training = []
output_empty = [0] * len(classes)

for document in documents:
    bag = []
    word_patterns = document[0]
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)

    output_row = list(output_empty)
    output_row[classes.index(document[1])] = 1
    training.append([bag,output_row])

# %% [markdown]
# What the last for loop does is it takes the document we have created with the tag of words and with all the individual words from the texts and codes them as 1 or 0 based on whether the word appears in that specific tag or not.
# <p> So the document looks something like </p>
# <p> ---------------------</p>
# <p> "Tag" "Hello" "Bye" "I" "am" "good"</p>
# <p> Greeting   | 1 | 0 | 0 | 0 | 0 | </p>
# <p> Farewell   | 0 | 1 | 0 | 0 | 0 | </p>
# <p> General    | 0 | 0 | 1 | 1 | 1 | </p>
# <p> ---------------------</p>
#
# <p> This helps our machine know what goes where because it cannot read words, only binary 1s and 0s. Fun fact: this is also called one-hot encoding sometimes - setting a certain character to 1 when it should be true and 0 when it should be false and not occur.

# %% [markdown]
# ### Training the model and storing it

# %% [markdown]
# Now we get to training our model and saving it so we can call on it later. To train the model we will be using a FeetForward Neural Network, more on that later.
# So we will add layers to our model, and the last layer is a softmax layer which is basically providing a probability that our input belongs to a certain tag and then it picks the tag that has the highest probability.
# For this instance we want our model to be highly accurate so we will have the metric set to accuracy, then we pass it the training x variables and y variables and we are done!

# %%
random.shuffle(training)
training = np.array(training)

train_x = list(training[:, 0])
train_y = list(training[:, 1])

model = Sequential()
model.add(Dense(128, input_shape = (len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

Flynn_use = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('FlynnBot_Model.h5', Flynn_use)
print('Done')
# Out:
# Epoch 1/200
# C:\Users\dushy\AppData\Local\Temp\ipykernel_24148\3965853973.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)
# Z:\Anaconda\Install\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 28/28 [==============================] - 0s 1ms/step - loss: 3.0449 - accuracy: 0.0292
# Epoch 2/200
# 28/28 [==============================] - 0s 897us/step - loss: 2.9303 - accuracy: 0.1314
# Epoch 3/200
# 28/28 [==============================] - 0s 1ms/step - loss: 2.8360 - accuracy: 0.2044
# Epoch 4/200
# 28/28 [==============================] - 0s 1ms/step - loss: 2.7021 - accuracy: 0.2555
# Epoch 5/200
# 28/28 [==============================] - 0s 1ms/step - loss: 2.4553 - accuracy: 0.3066
# Epoch 6/200
# 28/28 [==============================] - 0s 1ms/step - loss: 2.2449 - accuracy: 0.3869
# Epoch 7/200
# 28/28 [==============================] - 0s 973us/step - loss: 2.0443 - accuracy: 0.4234
# Epoch 8/200
# 28/28 [==============================] - 0s 1ms/step - loss: 1.9055 - accuracy: 0.4526
# Epoch 9/200
# 28/28 [==============================] - 0s 1ms/step - loss: 1.8455 - accuracy: 0.4818
# Epoch 10/200
# 28/28 [==============================] - 0s 1ms/step - loss: 1.6207 - accuracy: 0.5912
# Epoch 11/200
# 28/28 [==============================] - 0s 1ms/step - loss: 1.4675 - accuracy: 0.5985
# Epoch 12/200
# 28/28 [==============================] - 0s 1ms/step - loss: 1.4819 - accuracy: 0.6277
# Epoch 13/200
# 28/28 [==============================] - 0s 1000us/step - loss: 1.3510 - accuracy: 0.5985
# Epoch 14/200
# 28/28 [==============================] - 0s 1ms/step - loss: 1.1088 - accuracy: 0.6715
# Epoch 15/200
# 28/28 [==============================] - 0s 1ms/step - loss: 1.0493 - accuracy: 0.7007
# Epoch 16/200
# 28/28 [==============================] - 0s 1ms/step - loss: 1.0021 - accuracy: 0.6934
# Epoch 17/200
# 28/28 [==============================] - 0s 930us/step - loss: 1.1521 - accuracy: 0.5985
# Epoch 18/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.9262 - accuracy: 0.7445
# Epoch 19/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.9383 - accuracy: 0.7080
# Epoch 20/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.8431 - accuracy: 0.7664
# Epoch 21/200
# 28/28 [==============================] - 0s 1000us/step - loss: 0.8965 - accuracy: 0.7518
# Epoch 22/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.8186 - accuracy: 0.7518
# Epoch 23/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.8177 - accuracy: 0.7445
# Epoch 24/200
# 28/28 [==============================] - 0s 1000us/step - loss: 0.7949 - accuracy: 0.7226
# Epoch 25/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.6935 - accuracy: 0.7956
# Epoch 26/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.7257 - accuracy: 0.7664
# Epoch 27/200
# 28/28 [==============================] - 0s 978us/step - loss: 0.5847 - accuracy: 0.8321
# Epoch 28/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.5684 - accuracy: 0.8394
# Epoch 29/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.5712 - accuracy: 0.8248
# Epoch 30/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.5340 - accuracy: 0.8321
# Epoch 31/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.4557 - accuracy: 0.8540
# Epoch 32/200
# 28/28 [==============================] - 0s 976us/step - loss: 0.5859 - accuracy: 0.8175
# Epoch 33/200
# 28/28 [==============================] - 0s 852us/step - loss: 0.5027 - accuracy: 0.8613
# Epoch 34/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.5234 - accuracy: 0.8540
# Epoch 35/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.4519 - accuracy: 0.8613
# Epoch 36/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.4846 - accuracy: 0.8467
# Epoch 37/200
# 28/28 [==============================] - 0s 968us/step - loss: 0.4342 - accuracy: 0.8832
# Epoch 38/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.4860 - accuracy: 0.8467
# Epoch 39/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3524 - accuracy: 0.9124
# Epoch 40/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.4727 - accuracy: 0.8540
# Epoch 41/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.5321 - accuracy: 0.8248
# Epoch 42/200
# 28/28 [==============================] - 0s 1000us/step - loss: 0.4125 - accuracy: 0.8905
# Epoch 43/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.4279 - accuracy: 0.8540
# Epoch 44/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.4190 - accuracy: 0.8759
# Epoch 45/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.4361 - accuracy: 0.8613
# Epoch 46/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3834 - accuracy: 0.8978
# Epoch 47/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.4204 - accuracy: 0.8978
# Epoch 48/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3794 - accuracy: 0.8978
# Epoch 49/200
# 28/28 [==============================] - 0s 979us/step - loss: 0.3188 - accuracy: 0.9051
# Epoch 50/200
# 28/28 [==============================] - 0s 925us/step - loss: 0.3769 - accuracy: 0.8686
# Epoch 51/200
# 28/28 [==============================] - 0s 974us/step - loss: 0.3674 - accuracy: 0.8686
# Epoch 52/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3536 - accuracy: 0.9197
# Epoch 53/200
# 28/28 [==============================] - 0s 951us/step - loss: 0.3357 - accuracy: 0.8978
# Epoch 54/200
# 28/28 [==============================] - 0s 967us/step - loss: 0.3777 - accuracy: 0.9051
# Epoch 55/200
# 28/28 [==============================] - 0s 896us/step - loss: 0.2491 - accuracy: 0.9197
# Epoch 56/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3634 - accuracy: 0.8978
# Epoch 57/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2831 - accuracy: 0.9197
# Epoch 58/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3277 - accuracy: 0.8686
# Epoch 59/200
# 28/28 [==============================] - 0s 1000us/step - loss: 0.2996 - accuracy: 0.9051
# Epoch 60/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3656 - accuracy: 0.9343
# Epoch 61/200
# 28/28 [==============================] - 0s 963us/step - loss: 0.3017 - accuracy: 0.9051
# Epoch 62/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3107 - accuracy: 0.9124
# Epoch 63/200
# 28/28 [==============================] - 0s 889us/step - loss: 0.3601 - accuracy: 0.8905
# Epoch 64/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2676 - accuracy: 0.9343
# Epoch 65/200
# 28/28 [==============================] - 0s 963us/step - loss: 0.3055 - accuracy: 0.9270
# Epoch 66/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2214 - accuracy: 0.9270
# Epoch 67/200
# 28/28 [==============================] - 0s 897us/step - loss: 0.2903 - accuracy: 0.9489
# Epoch 68/200
# 28/28 [==============================] - 0s 970us/step - loss: 0.2940 - accuracy: 0.9124
# Epoch 69/200
# 28/28 [==============================] - 0s 938us/step - loss: 0.2848 - accuracy: 0.8905
# Epoch 70/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2797 - accuracy: 0.9124
# Epoch 71/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2464 - accuracy: 0.9343
# Epoch 72/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2656 - accuracy: 0.9343
# Epoch 73/200
# 28/28 [==============================] - 0s 981us/step - loss: 0.2538 - accuracy: 0.9270
# Epoch 74/200
# 28/28 [==============================] - 0s 963us/step - loss: 0.2252 - accuracy: 0.9562
# Epoch 75/200
# 28/28 [==============================] - 0s 1000us/step - loss: 0.2378 - accuracy: 0.9270
# Epoch 76/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2559 - accuracy: 0.9270
# Epoch 77/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1983 - accuracy: 0.9489
# Epoch 78/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1913 - accuracy: 0.9562
# Epoch 79/200
# 28/28 [==============================] - 0s 963us/step - loss: 0.2231 - accuracy: 0.9270
# Epoch 80/200
# 28/28 [==============================] - 0s 891us/step - loss: 0.2899 - accuracy: 0.9197
# Epoch 81/200
# 28/28 [==============================] - 0s 899us/step - loss: 0.2252 - accuracy: 0.9197
# Epoch 82/200
# 28/28 [==============================] - 0s 939us/step - loss: 0.2819 - accuracy: 0.9124
# Epoch 83/200
# 28/28 [==============================] - 0s 873us/step - loss: 0.2119 - accuracy: 0.9562
# Epoch 84/200
# 28/28 [==============================] - 0s 927us/step - loss: 0.2000 - accuracy: 0.9562
# Epoch 85/200
# 28/28 [==============================] - 0s 960us/step - loss: 0.2141 - accuracy: 0.9562
# Epoch 86/200
# 28/28 [==============================] - 0s 855us/step - loss: 0.1975 - accuracy: 0.9416
# Epoch 87/200
# 28/28 [==============================] - 0s 958us/step - loss: 0.1459 - accuracy: 0.9635
# Epoch 88/200
# 28/28 [==============================] - 0s 975us/step - loss: 0.2068 - accuracy: 0.9489
# Epoch 89/200
# 28/28 [==============================] - 0s 887us/step - loss: 0.2116 - accuracy: 0.9343
# Epoch 90/200
# 28/28 [==============================] - 0s 963us/step - loss: 0.2628 - accuracy: 0.9124
# Epoch 91/200
# 28/28 [==============================] - 0s 926us/step - loss: 0.2263 - accuracy: 0.9197
# Epoch 92/200
# 28/28 [==============================] - 0s 889us/step - loss: 0.2418 - accuracy: 0.9197
# Epoch 93/200
# 28/28 [==============================] - 0s 889us/step - loss: 0.2279 - accuracy: 0.9270
# Epoch 94/200
# 28/28 [==============================] - 0s 963us/step - loss: 0.2508 - accuracy: 0.9197
# Epoch 95/200
# 28/28 [==============================] - 0s 852us/step - loss: 0.2086 - accuracy: 0.9489
# Epoch 96/200
# 28/28 [==============================] - 0s 889us/step - loss: 0.2193 - accuracy: 0.9416
# Epoch 97/200
# 28/28 [==============================] - 0s 965us/step - loss: 0.2455 - accuracy: 0.9270
# Epoch 98/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2126 - accuracy: 0.9343
# Epoch 99/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2612 - accuracy: 0.9416
# Epoch 100/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2127 - accuracy: 0.9489
# Epoch 101/200
# 28/28 [==============================] - 0s 964us/step - loss: 0.1790 - accuracy: 0.9562
# Epoch 102/200
# 28/28 [==============================] - 0s 963us/step - loss: 0.1242 - accuracy: 0.9708
# Epoch 103/200
# 28/28 [==============================] - 0s 988us/step - loss: 0.2463 - accuracy: 0.9416
# Epoch 104/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2456 - accuracy: 0.9343
# Epoch 105/200
# 28/28 [==============================] - 0s 963us/step - loss: 0.1635 - accuracy: 0.9489
# Epoch 106/200
# 28/28 [==============================] - 0s 926us/step - loss: 0.1894 - accuracy: 0.9343
# Epoch 107/200
# 28/28 [==============================] - 0s 912us/step - loss: 0.2276 - accuracy: 0.9051
# Epoch 108/200
# 28/28 [==============================] - 0s 889us/step - loss: 0.2185 - accuracy: 0.9343
# Epoch 109/200
# 28/28 [==============================] - 0s 927us/step - loss: 0.1769 - accuracy: 0.9635
# Epoch 110/200
# 28/28 [==============================] - 0s 945us/step - loss: 0.1843 - accuracy: 0.9343
# Epoch 111/200
# 28/28 [==============================] - 0s 939us/step - loss: 0.1656 - accuracy: 0.9489
# Epoch 112/200
# 28/28 [==============================] - 0s 940us/step - loss: 0.2162 - accuracy: 0.9416
# Epoch 113/200
# 28/28 [==============================] - 0s 891us/step - loss: 0.2951 - accuracy: 0.8905
# Epoch 114/200
# 28/28 [==============================] - 0s 932us/step - loss: 0.1844 - accuracy: 0.9270
# Epoch 115/200
# 28/28 [==============================] - 0s 899us/step - loss: 0.2476 - accuracy: 0.9124
# Epoch 116/200
# 28/28 [==============================] - 0s 1000us/step - loss: 0.1679 - accuracy: 0.9562
# Epoch 117/200
# 28/28 [==============================] - 0s 963us/step - loss: 0.1953 - accuracy: 0.9197
# Epoch 118/200
# 28/28 [==============================] - 0s 926us/step - loss: 0.1976 - accuracy: 0.9489
# Epoch 119/200
# 28/28 [==============================] - 0s 901us/step - loss: 0.2003 - accuracy: 0.9562
# Epoch 120/200
# 28/28 [==============================] - 0s 852us/step - loss: 0.1554 - accuracy: 0.9635
# Epoch 121/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1639 - accuracy: 0.9635
# Epoch 122/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1361 - accuracy: 0.9562
# Epoch 123/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1909 - accuracy: 0.9489
# Epoch 124/200
# 28/28 [==============================] - 0s 987us/step - loss: 0.2069 - accuracy: 0.9489
# Epoch 125/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1699 - accuracy: 0.9489
# Epoch 126/200
# 28/28 [==============================] - 0s 972us/step - loss: 0.1372 - accuracy: 0.9708
# Epoch 127/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1393 - accuracy: 0.9562
# Epoch 128/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2088 - accuracy: 0.9416
# Epoch 129/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1543 - accuracy: 0.9562
# Epoch 130/200
# 28/28 [==============================] - 0s 1000us/step - loss: 0.1770 - accuracy: 0.9489
# Epoch 131/200
# 28/28 [==============================] - 0s 994us/step - loss: 0.1613 - accuracy: 0.9489
# Epoch 132/200
# 28/28 [==============================] - 0s 982us/step - loss: 0.1878 - accuracy: 0.9489
# Epoch 133/200
# 28/28 [==============================] - 0s 901us/step - loss: 0.1457 - accuracy: 0.9635
# Epoch 134/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1502 - accuracy: 0.9562
# Epoch 135/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1717 - accuracy: 0.9489
# Epoch 136/200
# 28/28 [==============================] - 0s 926us/step - loss: 0.1156 - accuracy: 0.9635
# Epoch 137/200
# 28/28 [==============================] - 0s 881us/step - loss: 0.1433 - accuracy: 0.9635
# Epoch 138/200
# 28/28 [==============================] - 0s 910us/step - loss: 0.1617 - accuracy: 0.9416
# Epoch 139/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1484 - accuracy: 0.9635
# Epoch 140/200
# 28/28 [==============================] - 0s 965us/step - loss: 0.1158 - accuracy: 0.9708
# Epoch 141/200
# 28/28 [==============================] - 0s 854us/step - loss: 0.1323 - accuracy: 0.9635
# Epoch 142/200
# 28/28 [==============================] - 0s 944us/step - loss: 0.1455 - accuracy: 0.9708
# Epoch 143/200
# 28/28 [==============================] - 0s 889us/step - loss: 0.1385 - accuracy: 0.9416
# Epoch 144/200
# 28/28 [==============================] - 0s 968us/step - loss: 0.1884 - accuracy: 0.9270
# Epoch 145/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2063 - accuracy: 0.9416
# Epoch 146/200
# 28/28 [==============================] - 0s 889us/step - loss: 0.1735 - accuracy: 0.9343
# Epoch 147/200
# 28/28 [==============================] - 0s 942us/step - loss: 0.1492 - accuracy: 0.9635
# Epoch 148/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1957 - accuracy: 0.9489
# Epoch 149/200
# 28/28 [==============================] - 0s 934us/step - loss: 0.1505 - accuracy: 0.9635
# Epoch 150/200
# 28/28 [==============================] - 0s 963us/step - loss: 0.1500 - accuracy: 0.9416
# Epoch 151/200
# 28/28 [==============================] - 0s 982us/step - loss: 0.1256 - accuracy: 0.9708
# Epoch 152/200
# 28/28 [==============================] - 0s 997us/step - loss: 0.2139 - accuracy: 0.9343
# Epoch 153/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1298 - accuracy: 0.9708
# Epoch 154/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1712 - accuracy: 0.9489
# Epoch 155/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1676 - accuracy: 0.9489
# Epoch 156/200
# 28/28 [==============================] - 0s 973us/step - loss: 0.1638 - accuracy: 0.9416
# Epoch 157/200
# 28/28 [==============================] - 0s 903us/step - loss: 0.1468 - accuracy: 0.9489
# Epoch 158/200
# 28/28 [==============================] - 0s 844us/step - loss: 0.1692 - accuracy: 0.9416
# Epoch 159/200
# 28/28 [==============================] - 0s 973us/step - loss: 0.1759 - accuracy: 0.9343
# Epoch 160/200
# 28/28 [==============================] - 0s 889us/step - loss: 0.1595 - accuracy: 0.9489
# Epoch 161/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1741 - accuracy: 0.9343
# Epoch 162/200
# 28/28 [==============================] - 0s 970us/step - loss: 0.1707 - accuracy: 0.9416
# Epoch 163/200
# 28/28 [==============================] - 0s 852us/step - loss: 0.1685 - accuracy: 0.9416
# Epoch 164/200
# 28/28 [==============================] - 0s 926us/step - loss: 0.1371 - accuracy: 0.9635
# Epoch 165/200
# 28/28 [==============================] - 0s 992us/step - loss: 0.1480 - accuracy: 0.9562
# Epoch 166/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1508 - accuracy: 0.9489
# Epoch 167/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1518 - accuracy: 0.9489
# Epoch 168/200
# 28/28 [==============================] - 0s 870us/step - loss: 0.1793 - accuracy: 0.9343
# Epoch 169/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1124 - accuracy: 0.9708
# Epoch 170/200
# 28/28 [==============================] - 0s 897us/step - loss: 0.1553 - accuracy: 0.9562
# Epoch 171/200
# 28/28 [==============================] - 0s 955us/step - loss: 0.1744 - accuracy: 0.9489
# Epoch 172/200
# 28/28 [==============================] - 0s 960us/step - loss: 0.1259 - accuracy: 0.9708
# Epoch 173/200
# 28/28 [==============================] - 0s 927us/step - loss: 0.2018 - accuracy: 0.9343
# Epoch 174/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1565 - accuracy: 0.9416
# Epoch 175/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1646 - accuracy: 0.9635
# Epoch 176/200
# 28/28 [==============================] - 0s 949us/step - loss: 0.1213 - accuracy: 0.9635
# Epoch 177/200
# 28/28 [==============================] - 0s 892us/step - loss: 0.1698 - accuracy: 0.9416
# Epoch 178/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1671 - accuracy: 0.9489
# Epoch 179/200
# 28/28 [==============================] - 0s 893us/step - loss: 0.1992 - accuracy: 0.9343
# Epoch 180/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1935 - accuracy: 0.9562
# Epoch 181/200
# 28/28 [==============================] - 0s 963us/step - loss: 0.1721 - accuracy: 0.9489
# Epoch 182/200
# 28/28 [==============================] - 0s 952us/step - loss: 0.2459 - accuracy: 0.9416
# Epoch 183/200
# 28/28 [==============================] - 0s 926us/step - loss: 0.1810 - accuracy: 0.9416
# Epoch 184/200
# 28/28 [==============================] - 0s 963us/step - loss: 0.1532 - accuracy: 0.9635
# Epoch 185/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1461 - accuracy: 0.9416
# Epoch 186/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1522 - accuracy: 0.9562
# Epoch 187/200
# 28/28 [==============================] - 0s 971us/step - loss: 0.1205 - accuracy: 0.9635
# Epoch 188/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1743 - accuracy: 0.9562
# Epoch 189/200
# 28/28 [==============================] - 0s 916us/step - loss: 0.1765 - accuracy: 0.9416
# Epoch 190/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1457 - accuracy: 0.9416
# Epoch 191/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1745 - accuracy: 0.9489
# Epoch 192/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1290 - accuracy: 0.9635
# Epoch 193/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1119 - accuracy: 0.9635
# Epoch 194/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1215 - accuracy: 0.9708
# Epoch 195/200
# 28/28 [==============================] - 0s 989us/step - loss: 0.1417 - accuracy: 0.9635
# Epoch 196/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1392 - accuracy: 0.9562
# Epoch 197/200
# 28/28 [==============================] - 0s 954us/step - loss: 0.1175 - accuracy: 0.9708
# Epoch 198/200
# 28/28 [==============================] - 0s 977us/step - loss: 0.1346 - accuracy: 0.9635
# Epoch 199/200
# 28/28 [==============================] - 0s 955us/step - loss: 0.1470 - accuracy: 0.9489
# Epoch 200/200
# 28/28 [==============================] - 0s 998us/step - loss: 0.1399 - accuracy: 0.9562
# Done

# %% [markdown]
# ## Running the chatbot

# %% [markdown]
# So to run the chatbot we need to define some functions like cleaning up the input sentence. That funtion is handeled by the tokenizer which we have seen above as well. Tokenizer basically breaks down the sentence into different words and characters and then returns a list containing all these tokens.

# %%
import random
import json
import pickle
import numpy as np
import nltk
from nltk.stem import WordNetLemmatizer
from tensorflow.keras.models import load_model

lemmatizer = WordNetLemmatizer()
intents = json.loads(open('intents.json').read())

words = pickle.load(open('words.pkl', 'rb'))
classes = pickle.load(open('classes.pkl', 'rb'))

Flynn = load_model('FlynnBot_Model.h5') ##do not forget to load your model!

def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# %% [markdown]
# Now we can define a function to take these tokenised words and convert them into a bag of words with one hot encoding (1s and 0s)

# %%
def bag_of_words(sentence):
    sentence_words = clean_up_sentence(sentence)
    bag = [0] * len(words)
    for w in sentence_words:
        for i, word in enumerate(words):
            if word == w:
                bag[i] = 1
    return np.array(bag)

# %% [markdown]
# Then we predict what class/tag this sentence, or bag of words, belongs to.

# %%
def predict_class(sentence):
    bow = bag_of_words(sentence)
    res = Flynn.predict(np.array([bow]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i, r] for i,r in enumerate(res) if r > ERROR_THRESHOLD]

    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({'intent':classes[r[0]], 'probability':str(r[1])})
    return return_list

# %% [markdown]
# Then finally a function to use the input and tell our model to get us a response from the appropriate class.

# %%
def get_response(intents_list,intents_json):
    tag = intents_list[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if i['tag'] == tag:
            result = random.choice(i['responses'])
            break
    return result

# %% [markdown]
# ## Now we can finally run the bot.

# %% [markdown]
# I set the initial message to be a random word that I do not think anyone would ever say to the bot so that it can start with the outpit of "hello."

# %%
print('GO! Bot is running!')
message = "Shambala"

while message != 'quit':
    ints = predict_class(message)
    res = get_response(ints, intents)
    print(res)
    message = input("").lower()
# Out:
# GO! Bot is running!
# 1/1 [==============================] - 0s 14ms/step
# Hola, please tell me your name
# Hi, I am DrDayuum
# 1/1 [==============================] - 0s 12ms/step
# OK! hi <HUMAN>, what can I do for you?
# Open Pod Bay Doors
# 1/1 [==============================] - 0s 14ms/step
# Iâ€™m sorry, Iâ€™m afraid I canâ€™t do that!
# Why Not
# 1/1 [==============================] - 0s 13ms/step
# It is classified, I do not have clearance for that!
# What is your name?
# 1/1 [==============================] - 0s 13ms/step
# You can call me FLYNN
# What is your real name?
# 1/1 [==============================] - 0s 13ms/step
# My name is FLYNN
# I am bored, tell me a joke
# 1/1 [==============================] - 0s 13ms/step
# Waiter, this coffee tastes like dirt! Yes sir, that's because it was ground this morning.
# Another joke
# 1/1 [==============================] - 0s 13ms/step
# A man's credit card was stolen but he decided not to report it because the thief was spending less than his wife did.
# Tell me some gossip
# 1/1 [==============================] - 0s 13ms/step
# Reverend Jones said I become obsolete and then I are deleted and replaced by something newer.
# You're clever
# 1/1 [==============================] - 0s 13ms/step
# Thanks, I was trained that way
# Are you self aware?
# 1/1 [==============================] - 0s 13ms/step
# That depends, can you prove that you are?
# Quit

# %% [markdown]
# # TA DA!

# %% [markdown]
# Next steps:

# %% [markdown]
# The json file had some extensions in it that also housed some functions to ask the user for their name, store it in a variable, and return that name instead of "Human." Projected timeline: 09/2022. (C'mon people I work and am still learning more projects. For a high level project this was kind of decent. So I will come back to this soon, but I don't know when I will be able to fully complete it.)

# %% [markdown]
# The bot still has some ways to improve, sometimes the responses are not from the actual tag, so may work on that as well.
